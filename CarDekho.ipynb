# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='ocean_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### No null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
print(df.Seller_Type.unique())
print(df.Fuel_Type.unique())
print(df.Transmission.unique())
print(df.Owner.unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df1 = df.drop("Car_Name",axis = 1)
df1
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df1['No_years'] = 2021 - df["Year"]
df1 = df1.drop("Year",axis =1)

# %%
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  No_years
# 0         Manual      0         7
# 1         Manual      0         8
# 2         Manual      0         4
# ...

# %%
df2 = pd.get_dummies(df1,drop_first=True)

# %%
df2
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  No_years  \
# 0             3.35           5.59       27000      0         7
# 1             4.75           9.54       43000      0         8
# 2             7.25           9.85        6900      0         4
# 3             2.85           4.15        5200      0        10
# 4             4.60           6.87       42450      0         7
# ..             ...            ...         ...    ...       ...
# 296           9.50          11.60       33988      0         5
# 297           4.00           5.90       60000      0         6
# 298           3.35          11.00       87934      0        12
# 299          11.50          12.50        9000      0         4
# 300           5.30           5.90        5464      0         5
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# ...

# %%
sns.pairplot(df2)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df2.corr(),cmap="Wistia",annot = True)
# Out:
# <AxesSubplot:>

# %%
X = df2.iloc[:,1:]

# %%
y = df2.iloc[:,0]

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.37389166, 0.04054896, 0.00037495, 0.07995322, 0.22089291,
#        0.01377352, 0.13623879, 0.13432599])

# %%
pd.DataFrame(model.feature_importances_,index = X.columns).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Hypertunning The Model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.22)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model2 = RandomForestRegressor()

# %%
n_estimators = [int(x) for x in np.linspace(100,1200,10)]
n_estimators
# Out:
# [100, 222, 344, 466, 588, 711, 833, 955, 1077, 1200]

# %%
max_features = ['auto','sqrt']

# %%
max_depth = [int(x) for x in np.linspace(5,30,6)]

# %%
min_samples_split = [2,5,10,15,100]

# %%
min_samples_leaf = [1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'n_estimators':n_estimators,
              'max_features':max_features,
              'max_depth':max_depth,
              'min_samples_split':min_samples_split,
               'min_samples_leaf':min_samples_leaf
              }
random_grid
# Out:
# {'n_estimators': [100, 222, 344, 466, 588, 711, 833, 955, 1077, 1200],
#  'max_features': ['auto', 'sqrt'],
#  'max_depth': [5, 10, 15, 20, 25, 30],
#  'min_samples_split': [2, 5, 10, 15, 100],
#  'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomizedSearchCV(estimator =  model2,param_distributions=random_grid,scoring='neg_mean_squared_error',n_iter=10,cv = 5,verbose=2,n_jobs = 1)

# %%
rf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time=   2.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time=   2.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time=   2.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time=   2.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1200; total time=   2.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=466; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=466; total time=   0.9s
# ...

# %%
predictions = rf.predict(X_test)
predictions
# Out:
# array([ 2.48509778,  1.47018476,  3.25415694,  5.12223175,  1.45087881,
#         5.49559627,  2.89708806,  3.10542103, 11.67097157,  5.28219127,
#         7.49571885,  4.03251548,  0.45389107,  1.2046119 ,  4.3366256 ,
#         7.77533166,  0.57324873,  0.49921206,  1.15415504,  4.44578905,
#         0.24695489,  9.13591627,  2.6388829 , 21.40749659,  5.22454845,
#         1.12916095,  5.62744325,  8.18888901,  3.71054599,  4.54751012,
#         2.8491866 ,  9.33592294,  4.39337679,  5.97873512,  2.75800611,
#         6.40627484,  3.93652163,  7.15816472,  2.58067231,  4.18386944,
#        17.84456298,  6.00849603,  4.65396468,  8.15108857,  0.6176175 ,
#         1.15248952,  0.45543679,  0.48246337,  4.20760635,  0.23506286,
#         7.51012774, 13.23435465,  1.29485452,  4.89600298,  3.38778988,
#         4.19837024,  0.24547087,  3.97139679,  3.41931508,  0.57421206,
#         5.18754544,  6.13172579,  0.46886956,  3.06938326,  4.68571071,
#         3.05073211,  0.43493391])

# %%
X_test.columns
# Out:
# Index(['Present_Price', 'Kms_Driven', 'Owner', 'No_years', 'Fuel_Type_Diesel',
#        'Fuel_Type_Petrol', 'Seller_Type_Individual', 'Transmission_Manual'],
#       dtype='object')

# %%
X_test.Seller_Type_Individual.unique()
# Out:
# array([0, 1], dtype=uint8)

# %%
sns.distplot(predictions,bins = 40)
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
import pickle

# %%
with open("tested.pickle",'wb') as f:
    pickle.dump(rf,f)

# %%
np.log(500)
# Out:
# 6.214608098422191

# %%
l = open('tested.pickle','rb')

# %%
clf = pickle.load(l)

# %%
clf.predict(X_test.iloc[[0]])
# Out:
# array([2.48509778])
